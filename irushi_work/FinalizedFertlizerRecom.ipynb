# %%
# !pip install openmeteo
# !pip install requests_cache retry-requests
# Out:
# ERROR: Could not find a version that satisfies the requirement openmeteo (from versions: none)
# ERROR: No matching distribution found for openmeteo
# Collecting requests_cache
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests_cache) (25.1.0)
# Collecting cattrs>=22.2 (from requests_cache)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests_cache) (4.3.6)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.11/dist-packages (from requests_cache) (2.32.3)
# Collecting url-normalize>=1.4 (from requests_cache)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.11/dist-packages (from requests_cache) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->requests_cache) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->requests_cache) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->requests_cache) (2025.1.31)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from url-normalize>=1.4->requests_cache) (1.17.0)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.2 MB/s eta 0:00:00
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.2 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, retry-requests, requests_cache
# Successfully installed cattrs-24.1.2 requests_cache-1.2.1 retry-requests-2.0.0 url-normalize-1.4.3

# %%
# !pip install open-meteo
# Out:
# Collecting open-meteo
#   Downloading open_meteo-0.3.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: aiohttp>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from open-meteo) (3.11.13)
# Collecting mashumaro>=3.10 (from open-meteo)
#   Downloading mashumaro-3.15-py3-none-any.whl.metadata (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.9.8 in /usr/local/lib/python3.11/dist-packages (from open-meteo) (3.10.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->open-meteo) (1.18.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from mashumaro>=3.10->open-meteo) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.8.1->open-meteo) (3.10)
# Downloading open_meteo-0.3.2-py3-none-any.whl (10 kB)
# Downloading mashumaro-3.15-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: mashumaro, open-meteo
# Successfully installed mashumaro-3.15 open-meteo-0.3.2

# %%
# !pip install retrying
# Out:
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying) (1.17.0)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: retrying
# Successfully installed retrying-1.3.4

# %%
pip install openmeteo-requests
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.3.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting openmeteo-sdk>=1.4.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.19.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmeteo-requests) (2.32.3)
# Requirement already satisfied: flatbuffers==25.2.10 in /usr/local/lib/python3.11/dist-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (25.2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmeteo-requests) (2025.1.31)
# Downloading openmeteo_requests-1.3.0-py3-none-any.whl (6.0 kB)
# Downloading openmeteo_sdk-1.19.0-py3-none-any.whl (15 kB)
# Installing collected packages: openmeteo-sdk, openmeteo-requests
# Successfully installed openmeteo-requests-1.3.0 openmeteo-sdk-1.19.0

# %%
from abc import ABC, abstractmethod
import json
import requests
import openmeteo_requests
import requests_cache
from retry_requests import retry

# Load domain knowledge from JSON file
with open('domain_knowledge.json', 'r') as f:
    DOMAIN_KNOWLEDGE = json.load(f)

# Open-Meteo API setup
cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

# IP Stack API Setup
API_KEY = "417d58eb281d803c8f457e3e6f47dc57"
ipstack_url = f"http://api.ipstack.com/check?access_key={API_KEY}"

def get_user_location():
    """Fetch user's current location (latitude, longitude) and city using IP Stack."""
    try:
        response = requests.get(ipstack_url)
        data = response.json()
        lat = data.get('latitude')
        lon = data.get('longitude')
        city = data.get('city', 'Unknown')
        if lat is None or lon is None:
            raise ValueError("Invalid location data returned from IP Stack.")
        return lat, lon, city
    except Exception as e:
        print(f"Error fetching location: {e}")
        return None, None, None

def get_weather_data(lat, lon):
    """Fetch current weather data from Open-Meteo API using latitude and longitude."""
    try:
        url = "https://api.open-meteo.com/v1/forecast"
        params = {
            "latitude": lat,
            "longitude": lon,
            "current": ["temperature_2m", "relative_humidity_2m"]
        }
        responses = openmeteo.weather_api(url, params=params)
        response = responses[0]
        current = response.Current()
        temperature = current.Variables(0).Value()  # temperature_2m
        humidity = current.Variables(1).Value()     # relative_humidity_2m
        return humidity, temperature
    except Exception as e:
        print(f"Error fetching weather data: {e}")
        return None, None

# Abstract Base Classes
class SoilBase(ABC):
    def __init__(self, soil_type, pH):
        self.soil_type = soil_type
        self.pH = pH

    @abstractmethod
    def get_soil_type(self):
        pass

    @abstractmethod
    def get_soil_nutrient(self, nutrient):
        pass

    @abstractmethod
    def is_suitable_for_plant(self, plant_name):
        pass

class EnvironmentBase(ABC):
    def __init__(self, temperature, humidity):
        self.temperature = temperature
        self.humidity = humidity

    @abstractmethod
    def get_temperature(self):
        pass

    @abstractmethod
    def get_humidity(self):
        pass

    @abstractmethod
    def check_suitability(self, plant_type):
        pass

class PlantBase(ABC):
    @abstractmethod
    def get_name(self):
        pass

    @abstractmethod
    def get_required_nutrients(self):
        pass

    @abstractmethod
    def check_growth_conditions(self, environment):
        pass

class DeficiencyBase(ABC):
    @abstractmethod
    def get_deficiency_name(self):
        pass

    @abstractmethod
    def assess_severity(self, symptoms):
        pass

    @abstractmethod
    def recommend_treatment(self, severity):
        pass

class FertilizerStrategyBase(ABC):
    @abstractmethod
    def get_fertilizer_recommendation(self, severity):
        pass

    @abstractmethod
    def get_application_guidelines(self):
        pass

# Concrete Classes
class Soil(SoilBase):
    def __init__(self, soil_type, pH, nutrient_levels):
        super().__init__(soil_type, pH)
        self.nutrient_levels = nutrient_levels

    def get_soil_type(self):
        return self.soil_type

    def is_suitable_for_plant(self, plant_name):
        soil_preferences = DOMAIN_KNOWLEDGE["soil_preferences"]
        if plant_name in soil_preferences:
            prefs = soil_preferences[plant_name]
            if prefs["pH_range"][0] <= self.pH <= prefs["pH_range"][1] and self.soil_type in prefs["suitable_soils"]:
                return f"✅ Suitable: {self.soil_type} soil with pH {self.pH} is ideal for {plant_name}."
            else:
                return f"⚠️ Not Suitable: {plant_name} prefers {prefs['suitable_soils']} soil with pH between {prefs['pH_range'][0]} and {prefs['pH_range'][1]}, but got {self.soil_type} with pH {self.pH}."
        return "❌ Unknown plant type. Cannot determine soil suitability."

    def get_soil_nutrient(self, nutrient):
        level = self.nutrient_levels.get(nutrient)
        if level is not None:
            return f"✅ {nutrient} level in soil: {level} ppm."
        else:
            return f"⚠️ {nutrient} not found in soil data."

class Environment(EnvironmentBase):
    def __init__(self, temperature, humidity):
        super().__init__(temperature, humidity)

    def get_temperature(self):
        return self.temperature

    def get_humidity(self):
        return self.humidity

    def check_suitability(self, plant_type):
        plant_conditions = DOMAIN_KNOWLEDGE["plant_conditions"]
        if plant_type in plant_conditions:
            conditions = plant_conditions[plant_type]
            temp_ok = conditions["temp_range"][0] <= self.temperature <= conditions["temp_range"][1]
            humidity_ok = conditions["humidity_range"][0] <= self.humidity <= conditions["humidity_range"][1]
            if temp_ok and humidity_ok:
                return f"✅ Environment suitable: Temperature {self.temperature}°C & Humidity {self.humidity}% are within optimal range for {plant_type}."
            else:
                return f"⚠️ Not Suitable: {plant_type} requires temperature {conditions['temp_range']}°C & humidity {conditions['humidity_range']}%, but got {self.temperature}°C and {self.humidity}%."
        return "❌ Unknown plant type. Cannot determine environmental suitability."

class Plant(PlantBase):
    def __init__(self, name, soil, environment):
        self.name = name
        self.soil = soil
        self.environment = environment

    def get_name(self):
        return self.name

    def get_required_nutrients(self):
        return DOMAIN_KNOWLEDGE["nutrient_requirements"].get(self.name, {})

    def check_growth_conditions(self, environment):
        return self.environment.check_suitability(self.name)

class BananaPlant(Plant):
    def __init__(self, soil, environment):
        super().__init__("Banana", soil, environment)

class CoffeePlant(Plant):
    def __init__(self, soil, environment):
        super().__init__("Coffee", soil, environment)

class RicePlant(Plant):
    def __init__(self, soil, environment):
        super().__init__("Rice", soil, environment)

class DeficiencyEvaluator:
    def __init__(self, deficiency_type, severity_level):
        self.deficiency_type = deficiency_type
        self.severity_level = severity_level

    def evaluate_deficiency(self):
        recommendations = DOMAIN_KNOWLEDGE["fertilizer_recommendations"]
        recommendation_text = recommendations.get(self.deficiency_type, {}).get(self.severity_level, "No specific recommendation available.")
        return {
            "Deficiency": self.deficiency_type,
            "Severity": self.severity_level,
            "Recommendation": recommendation_text
        }

class FertilizerStrategyLow(FertilizerStrategyBase):
    def get_fertilizer_recommendation(self, severity):
        return DOMAIN_KNOWLEDGE["fertilizer_recommendations"]

    def get_application_guidelines(self):
        return DOMAIN_KNOWLEDGE["fertilizer_application_guidelines"]

    def get_recommendation(self, deficiency_type):
        return DOMAIN_KNOWLEDGE["fertilizer_recommendations"].get(deficiency_type, {}).get("Mild", "No recommendation available for this deficiency.")

class FertilizerStrategyMedium(FertilizerStrategyBase):
    def get_fertilizer_recommendation(self, severity):
        return DOMAIN_KNOWLEDGE["fertilizer_recommendations"]

    def get_application_guidelines(self):
        return DOMAIN_KNOWLEDGE["fertilizer_application_guidelines"]

    def get_recommendation(self, deficiency_type):
        return DOMAIN_KNOWLEDGE["fertilizer_recommendations"].get(deficiency_type, {}).get("Moderate", "No recommendation available for this deficiency.")

class FertilizerStrategyHigh(FertilizerStrategyBase):
    def get_fertilizer_recommendation(self, severity):
        return DOMAIN_KNOWLEDGE["fertilizer_recommendations"]

    def get_application_guidelines(self):
        return DOMAIN_KNOWLEDGE["fertilizer_application_guidelines"]

    def get_recommendation(self, deficiency_type):
        return DOMAIN_KNOWLEDGE["fertilizer_recommendations"].get(deficiency_type, {}).get("Severe", "No recommendation available for this deficiency.")

class FertilizerPipeline:
    def __init__(self):
        self.recommendation_engine = RecommendationEngine()

    def run(self, soil_type, plant_type, deficiency_type, severity_level):
        # Get user's location
        lat, lon, city = get_user_location()
        if lat is None or lon is None:
            raise Exception("Could not fetch location data. Please check your connection or IP Stack API key.")

        # Fetch weather data
        humidity, temperature = get_weather_data(lat, lon)
        if humidity is None or temperature is None:
            raise Exception("Could not fetch weather data. Please check the Open-Meteo API.")
        print(f"Location: {city} | Temperature: {temperature}°C | Humidity: {humidity}%")

        # Fixed soil parameters (could be made dynamic if needed)
        pH = 6.5
        nutrient_levels = {"N": 40, "P": 30, "K": 50}

        soil = Soil(soil_type, pH, nutrient_levels)
        environment = Environment(temperature, humidity)

        soil_suitability = soil.is_suitable_for_plant(plant_type)
        environment_status = environment.check_suitability(plant_type)

        recommendation = self.recommendation_engine.get_fertilizer_recommendation(
            plant=plant_type,
            deficiency=deficiency_type,
            severity=severity_level,
            soil_suitability=soil_suitability,
            temperature_status=environment_status,
            humidity_status=environment_status
        )
        return recommendation

class RecommendationEngine:
    def __init__(self):
        self.strategies = {
            "Mild": FertilizerStrategyLow(),
            "Moderate": FertilizerStrategyMedium(),
            "Severe": FertilizerStrategyHigh()
        }

    def get_fertilizer_recommendation(self, plant, deficiency, severity, soil_suitability, temperature_status, humidity_status):
        strategy = self.strategies.get(severity, None)
        if not strategy:
            return f"Error: Invalid severity level '{severity}'. Expected: Mild, Moderate, or Severe."

        recommendation = strategy.get_recommendation(deficiency)
        guidelines = strategy.get_application_guidelines()

        output_message = f"""
        === Fertilizer Recommendations ===
        Plant: {plant}
        Deficiency: {deficiency}
        Severity: {severity}
        Recommendation: {recommendation}

        === Additional Details ===
        Soil Suitability: {soil_suitability}
        Temperature Status: {temperature_status}
        Humidity Status: {humidity_status}

        #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
        - **Application Methods:**
          - **Even & Precise Spreading:** {guidelines['Application_Methods']['Even_Precise_Spreading']}
          - **Split Applications:**
            - **Nitrogen:** {guidelines['Application_Methods']['Split_Applications']['Nitrogen']}
            - **Phosphorus, Potassium, Zinc:** {guidelines['Application_Methods']['Split_Applications']['Phosphorus_Potassium_Zinc']}
          - **Equipment & Conditions:** {guidelines['Application_Methods']['Equipment_Conditions']}

        - **General Best Practices:**
          - **Quality & Consistency:** {guidelines['General_Best_Practices']['Quality_Consistency']}
          - **Timing & Precision:** {guidelines['General_Best_Practices']['Timing_Precision']}
          - **Zone-Specific Recommendations:** {guidelines['General_Best_Practices']['Zone_Specific_Recommendations']}
        """
        return output_message.strip()

# Example usage
if __name__ == "__main__":
    pipeline = FertilizerPipeline()
    plant_deficiency_map = DOMAIN_KNOWLEDGE["plant_deficiency_map"]
    severity_levels = DOMAIN_KNOWLEDGE["severity_levels"]

    # Get soil type from user
    soil_type = input("Enter soil type (e.g., Loamy, Sandy, Clay): ").strip()

    # Simulate inputs from previous components (replace with actual integration)
    for plant, deficiencies in plant_deficiency_map.items():
        for deficiency in deficiencies:
            for severity in severity_levels:
                print("\n" + "="*50)
                print(f"Generating Fertilizer Recommendation for {plant} | {deficiency} | {severity}\n")
                try:
                    result = pipeline.run(
                        soil_type=soil_type,
                        plant_type=plant,
                        deficiency_type=deficiency,
                        severity_level=severity
                    )
                    print(result)
                except Exception as e:
                    print(f"Error: {e}")
                print("="*50 + "\n")
# Out:
# Enter soil type (e.g., Loamy, Sandy, Clay): clay
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Magnesium | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Magnesium
#         Severity: Mild
#         Recommendation: Foliar spray of 5% MgSO4 or dolomite limestone at 3 t/ha.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Magnesium | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Magnesium
#         Severity: Moderate
#         Recommendation: Apply 30-50 kg/ha of MgSO4 to the soil.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Magnesium | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Magnesium
#         Severity: Severe
#         Recommendation: Apply 100 kg/ha of MgSO4 with irrigation water.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Iron | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Iron
#         Severity: Mild
#         Recommendation: Soil application of FeSO4 (5 g/ha) or foliar spray of 0.5% FeSO4 weekly.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Iron | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Iron
#         Severity: Moderate
#         Recommendation: Apply 10 g/ha of FeSO4 to the soil and monitor symptoms.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Iron | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Iron
#         Severity: Severe
#         Recommendation: Apply chelated iron (EDDHA-Fe) for rapid correction.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Potassium | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Potassium
#         Severity: Mild
#         Recommendation: Foliar spray of 2% KCl weekly until symptoms disappear.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Potassium | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Potassium
#         Severity: Moderate
#         Recommendation: Apply 40 kg/ha of K2O and monitor plant response.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Banana | Potassium | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Banana
#         Deficiency: Potassium
#         Severity: Severe
#         Recommendation: Apply 80 kg/ha of K2O and incorporate into the soil.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Banana prefers ['Loamy', 'Clay'] soil with pH between 5.5 and 7.0, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Banana requires temperature [18, 30]°C & humidity [50, 80]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Magnesium | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Magnesium
#         Severity: Mild
#         Recommendation: Foliar spray of 5% MgSO4 or dolomite limestone at 3 t/ha.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Magnesium | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Magnesium
#         Severity: Moderate
#         Recommendation: Apply 30-50 kg/ha of MgSO4 to the soil.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Magnesium | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Magnesium
#         Severity: Severe
#         Recommendation: Apply 100 kg/ha of MgSO4 with irrigation water.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Iron | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Iron
#         Severity: Mild
#         Recommendation: Soil application of FeSO4 (5 g/ha) or foliar spray of 0.5% FeSO4 weekly.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Iron | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Iron
#         Severity: Moderate
#         Recommendation: Apply 10 g/ha of FeSO4 to the soil and monitor symptoms.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Iron | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Iron
#         Severity: Severe
#         Recommendation: Apply chelated iron (EDDHA-Fe) for rapid correction.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Potassium | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Potassium
#         Severity: Mild
#         Recommendation: Foliar spray of 2% KCl weekly until symptoms disappear.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Potassium | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Potassium
#         Severity: Moderate
#         Recommendation: Apply 40 kg/ha of K2O and monitor plant response.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Coffee | Potassium | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Coffee
#         Deficiency: Potassium
#         Severity: Severe
#         Recommendation: Apply 80 kg/ha of K2O and incorporate into the soil.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Coffee prefers ['Loamy', 'Sandy'] soil with pH between 5.0 and 6.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Coffee requires temperature [15, 28]°C & humidity [60, 90]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Nitrogen | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Nitrogen
#         Severity: Mild
#         Recommendation: Apply 20-30 kg/ha of urea as a foliar spray.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Nitrogen | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Nitrogen
#         Severity: Moderate
#         Recommendation: Apply 50 kg/ha of urea in split doses.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Nitrogen | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Nitrogen
#         Severity: Severe
#         Recommendation: Apply 80-100 kg/ha of urea with soil incorporation.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Phosphorus | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Phosphorus
#         Severity: Mild
#         Recommendation: Apply 15-25 kg/ha of superphosphate.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Phosphorus | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Phosphorus
#         Severity: Moderate
#         Recommendation: Apply 40 kg/ha of superphosphate.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Phosphorus | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Phosphorus
#         Severity: Severe
#         Recommendation: Apply 60 kg/ha of superphosphate, deep placement.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Potassium | Mild
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Potassium
#         Severity: Mild
#         Recommendation: Foliar spray of 2% KCl weekly until symptoms disappear.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Potassium | Moderate
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Potassium
#         Severity: Moderate
#         Recommendation: Apply 40 kg/ha of K2O and monitor plant response.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
#
#
# ==================================================
# Generating Fertilizer Recommendation for Rice | Potassium | Severe
#
# Location: Hanahan | Temperature: 9.337000846862793°C | Humidity: 71.0%
# === Fertilizer Recommendations ===
#         Plant: Rice
#         Deficiency: Potassium
#         Severity: Severe
#         Recommendation: Apply 80 kg/ha of K2O and incorporate into the soil.
#
#         === Additional Details ===
#         Soil Suitability: ⚠️ Not Suitable: Rice prefers ['Clay', 'Loamy'] soil with pH between 5.5 and 7.5, but got clay with pH 6.5.
#         Temperature Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#         Humidity Status: ⚠️ Not Suitable: Rice requires temperature [20, 35]°C & humidity [70, 100]%, but got 9.337000846862793°C and 71.0%.
#
#         #### **Fertilizer Application Guidelines (Applicable to Banana, Coffee & Rice)**
#         - **Application Methods:**
#           - **Even & Precise Spreading:** Use calibrated spreaders and perform tray tests to ensure even distribution.
#           - **Split Applications:**
#             - **Nitrogen:** Apply in multiple splits—50% before transplanting, 25% at 30 days, 25% at panicle initiation.
#             - **Phosphorus, Potassium, Zinc:** Typically applied as a basal dose.
#           - **Equipment & Conditions:** Adjust spreader settings based on weather to avoid uneven application.
#
#         - **General Best Practices:**
#           - **Quality & Consistency:** Use high-quality fertilizers and store them properly.
#           - **Timing & Precision:** Apply nutrients when crops need them most.
#           - **Zone-Specific Recommendations:** Follow field zone-based tables for tailored application rates.
# ==================================================
